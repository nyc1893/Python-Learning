# %%
import pandas as pd

# %%
df = pd.read_csv('https://raw.githubusercontent.com/KFFData/COVID-19-Data/kff_master/Country%20Trend%20Data/global_covid_metrics2022_H2.csv')
df
# Out:
#                  Country        Date  Confirmed Cases  Confirmed Deaths  \
# 0            Afghanistan  2022-07-01           182594              7723
# 1                Albania  2022-07-01           281470              3501
# 2                Algeria  2022-07-01           266105              6875
# 3         American Samoa  2022-07-01             6505                31
# 4                Andorra  2022-07-01            44177               153
# ...                  ...         ...              ...               ...
# 24331            Vietnam  2022-10-12         11489881             43155
# 24332  Wallis and Futuna  2022-10-12              761                 7
# 24333              Yemen  2022-10-12            11939              2158
# 24334             Zambia  2022-10-12           333624              4017
# 24335           Zimbabwe  2022-10-12           257798              5604
#
#        New Cases  New Deaths               Income  \
# 0             66           0           Low income
# ...

# %%
df.shape
# Out:
# (24336, 32)

# %%
list(df)
# Out:
# ['Country',
#  'Date',
#  'Confirmed Cases',
#  'Confirmed Deaths',
#  'New Cases',
#  'New Deaths',
#  'Income',
#  'Region',
#  'Population',
#  'Case_Change_7_Day_Rolling_Average',
#  'Death_Change_7_Day_Rolling_Average',
#  'year',
#  'cpm',
#  'dpm',
#  'new_cases_per_million',
#  'new_deaths_per_million',
#  'cases_income',
#  'deaths_income',
#  'cpm_income',
#  'dpm_income',
#  'Case_7_Day_income',
#  'Death_7_Day_income',
#  'Case_7_Day_income_per_million',
#  'Death_7_Day_income_per_million',
#  'cases_region',
#  'deaths_region',
#  'cpm_region',
#  'dpm_region',
#  'Case_7_Day_region',
#  'Death_7_Day_region',
#  'Case_7_Day_region_per_million',
#  'Death_7_Day_region_per_million']

# %%
list(df['Country'].unique())
# Out:
# ['Afghanistan',
#  'Albania',
#  'Algeria',
#  'American Samoa',
#  'Andorra',
#  'Angola',
#  'Anguilla',
#  'Antarctica',
#  'Antigua and Barbuda',
#  'Argentina',
#  'Armenia',
#  'Aruba',
#  'Australia',
#  'Austria',
#  'Azerbaijan',
#  'Bahamas',
#  'Bahrain',
#  'Bangladesh',
#  'Barbados',
#  'Belarus',
#  'Belgium',
#  'Belize',
#  'Benin',
#  'Bermuda',
#  'Bhutan',
#  'Bolivia',
#  'Bosnia and Herzegovina',
#  'Botswana',
#  'Brazil',
#  'British Virgin Islands',
#  'Brunei',
#  'Bulgaria',
#  'Burkina Faso',
#  'Burundi',
#  'Cambodia',
#  'Cameroon',
#  'Canada',
#  'Cape Verde',
#  'Bonaire, Sint Eustatius and Saba',
#  'Cayman Islands',
#  'Central African Republic',
#  'Chad',
#  'Channel Islands',
#  'Chile',
#  'China',
#  'Colombia',
#  'Comoros',
#  'Congo (Brazzaville)',
#  'Congo (Kinshasa)',
#  'Cook Islands',
#  'Costa Rica',
#  "Cote d'Ivoire",
#  'Croatia',
#  'Cuba',
#  'Curacao',
#  'Cyprus',
#  'Czechia',
#  'Denmark',
#  'Djibouti',
#  'Dominica',
# ...

# %%
df.groupby(['Country'])[['Country']].nunique().count().rename({'Country' : 'Total Number of Countries:'})
# Out:
# Total Number of Countries:    234
# dtype: int64

# %%
list(df['Date'].unique())
# Out:
# ['2022-07-01',
#  '2022-07-02',
#  '2022-07-03',
#  '2022-07-04',
#  '2022-07-05',
#  '2022-07-06',
#  '2022-07-07',
#  '2022-07-08',
#  '2022-07-09',
#  '2022-07-10',
#  '2022-07-11',
#  '2022-07-12',
#  '2022-07-13',
#  '2022-07-14',
#  '2022-07-15',
#  '2022-07-16',
#  '2022-07-17',
#  '2022-07-18',
#  '2022-07-19',
#  '2022-07-20',
#  '2022-07-21',
#  '2022-07-22',
#  '2022-07-23',
#  '2022-07-24',
#  '2022-07-25',
#  '2022-07-26',
#  '2022-07-27',
#  '2022-07-28',
#  '2022-07-29',
#  '2022-07-30',
#  '2022-07-31',
#  '2022-08-01',
#  '2022-08-02',
#  '2022-08-03',
#  '2022-08-04',
#  '2022-08-05',
#  '2022-08-06',
#  '2022-08-07',
#  '2022-08-08',
#  '2022-08-09',
#  '2022-08-10',
#  '2022-08-11',
#  '2022-08-12',
#  '2022-08-13',
#  '2022-08-14',
#  '2022-08-15',
#  '2022-08-16',
#  '2022-08-17',
#  '2022-08-18',
#  '2022-08-19',
#  '2022-08-20',
#  '2022-08-21',
#  '2022-08-22',
#  '2022-08-23',
#  '2022-08-24',
#  '2022-08-25',
#  '2022-08-26',
#  '2022-08-27',
# ...

# %%
df.groupby(['Date'])[['Date']].nunique().count().rename({'Date' : 'Total Number of Days:'})
# Out:
# Total Number of Days:    104
# dtype: int64

# %%
df.keys()
# Out:
# Index(['Country', 'Date', 'Confirmed Cases', 'Confirmed Deaths', 'New Cases',
#        'New Deaths', 'Income', 'Region', 'Population',
#        'Case_Change_7_Day_Rolling_Average',
#        'Death_Change_7_Day_Rolling_Average', 'year', 'cpm', 'dpm',
#        'new_cases_per_million', 'new_deaths_per_million', 'cases_income',
#        'deaths_income', 'cpm_income', 'dpm_income', 'Case_7_Day_income',
#        'Death_7_Day_income', 'Case_7_Day_income_per_million',
#        'Death_7_Day_income_per_million', 'cases_region', 'deaths_region',
#        'cpm_region', 'dpm_region', 'Case_7_Day_region', 'Death_7_Day_region',
#        'Case_7_Day_region_per_million', 'Death_7_Day_region_per_million'],
#       dtype='object')

# %%
df.describe()
# Out:
#        Confirmed Cases  Confirmed Deaths      New Cases    New Deaths  \
# count     2.433600e+04      2.433600e+04   24336.000000  24336.000000
# mean      2.529634e+06      2.764401e+04    3097.386793      8.320800
# std       8.239821e+06      9.768267e+04   16686.828529     45.388518
# min       0.000000e+00      0.000000e+00       0.000000      0.000000
# 25%       2.154400e+04      1.630000e+02       0.000000      0.000000
# 50%       1.855165e+05      1.637000e+03       0.000000      0.000000
# 75%       1.168055e+06      1.339075e+04     183.000000      0.000000
# max       9.576878e+07      1.058267e+06  406322.000000   1515.000000
#
#          Population  Case_Change_7_Day_Rolling_Average  \
# count  2.402400e+04                       24336.000000
# mean   3.391405e+07                        3144.495034
# std    1.375778e+08                       14325.053057
# min    5.200000e+02                           0.000000
# 25%    3.949210e+05                           2.428571
# ...

# %%
df.mean()
# Out:
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:1: FutureWarning: Dropping of nuisance columns in DataFrame reductions (with 'numeric_only=None') is deprecated; in a future version this will raise TypeError.  Select only valid columns before calling the reduction.
#   """Entry point for launching an IPython kernel.
# Confirmed Cases                       2.529634e+06
# Confirmed Deaths                      2.764401e+04
# New Cases                             3.097387e+03
# New Deaths                            8.320800e+00
# Population                            3.391405e+07
# Case_Change_7_Day_Rolling_Average     3.144495e+03
# Death_Change_7_Day_Rolling_Average    8.342872e+00
# year                                  2.020000e+03
# cpm                                   1.788547e+05
# dpm                                   1.189436e+03
# new_cases_per_million                 2.298680e+02
# new_deaths_per_million                4.537552e-01
# ...

# %%
#df.groupby(['Country']).get_group('United States')

#           OR

country_grp = df.groupby(['Country'])
country_grp.get_group('United States')
# Out:
#              Country        Date  Confirmed Cases  Confirmed Deaths  \
# 223    United States  2022-07-01         86990778           1013094
# 457    United States  2022-07-02         87007462           1013130
# 691    United States  2022-07-03         87014230           1013135
# 925    United States  2022-07-04         87090167           1013212
# 1159   United States  2022-07-05         87231547           1013669
# ...              ...         ...              ...               ...
# 23389  United States  2022-10-08         95630900           1056827
# 23623  United States  2022-10-09         95635164           1056829
# 23857  United States  2022-10-10         95656546           1056946
# 24091  United States  2022-10-11         95704742           1057523
# 24325  United States  2022-10-12         95768783           1058267
#
#        New Cases  New Deaths       Income                  Region  \
# 223       153361         494  High income  Region of the Americas
# ...

# %%
#df.loc[df['Country'] == 'Brazil']

#         OR

filt = df['Country'] == 'Brazil'
df.loc[filt]
# Out:
#       Country        Date  Confirmed Cases  Confirmed Deaths  New Cases  \
# 28     Brazil  2022-07-01         32434063            671700      76045
# 262    Brazil  2022-07-02         32471847            671858      37784
# 496    Brazil  2022-07-03         32490422            671911      18575
# 730    Brazil  2022-07-04         32535923            672033      45501
# 964    Brazil  2022-07-05         32610514            672429      74591
# ...       ...         ...              ...               ...        ...
# 23194  Brazil  2022-10-08         34707233            686706          0
# 23428  Brazil  2022-10-09         34707233            686706          0
# 23662  Brazil  2022-10-10         34724189            686877      16956
# 23896  Brazil  2022-10-11         34731539            686963       7350
# 24130  Brazil  2022-10-12         34731539            686963          0
#
#        New Deaths               Income                  Region   Population  \
# ...

# %%
country_grp['Confirmed Cases', 'New Cases'].describe()
# Out:
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:1: FutureWarning: Indexing with multiple keys (implicitly converted to a tuple of keys) will be deprecated, use a list instead.
#   """Entry point for launching an IPython kernel.
#                    Confirmed Cases                                         \
#                              count           mean           std       min
# Country
# Afghanistan                  104.0  191113.605769   6103.718436  182594.0
# Albania                      104.0  318058.721154  16513.860816  281470.0
# Algeria                      104.0  268972.990385   1771.746094  266105.0
# American Samoa               104.0    7791.567308    595.930092    6505.0
# Andorra                      104.0   45703.634615    605.253859   44177.0
# ...                            ...            ...           ...       ...
# Wallis and Futuna            104.0     691.115385    123.287832     454.0
# ...

# %%
country_grp['Confirmed Cases', 'New Cases'].agg(['count', 'mean', 'std', 'min', 'median', 'max', 'sum'])
# Out:
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:1: FutureWarning: Indexing with multiple keys (implicitly converted to a tuple of keys) will be deprecated, use a list instead.
#   """Entry point for launching an IPython kernel.
#                    Confirmed Cases                                       \
#                              count           mean           std     min
# Country
# Afghanistan                    104  191113.605769   6103.718436  182594
# Albania                        104  318058.721154  16513.860816  281470
# Algeria                        104  268972.990385   1771.746094  266105
# American Samoa                 104    7791.567308    595.930092    6505
# Andorra                        104   45703.634615    605.253859   44177
# ...                            ...            ...           ...     ...
# Wallis and Futuna              104     691.115385    123.287832     454
# West Bank and Gaza             104  690558.230769  15506.229094  659853
# ...

# %%
country_grp[['Confirmed Cases', 'New Cases']].describe().loc[['United States']]
# Out:
#               Confirmed Cases                                          \
#                         count          mean           std         min
# Country
# United States           104.0  9.217607e+07  2.705211e+06  86990778.0
#
#                                                                New Cases  \
#                        25%         50%         75%         max     count
# Country
# United States  90008934.25  92616130.0  94612121.5  95768783.0     104.0
#
#                                                                                \
#                        mean           std     min      25%      50%       75%
# Country
# United States  85878.519231  62875.524346  4264.0  22766.5  80724.5  134591.0
#
#
#                     max
# Country
# United States  237315.0

# %%
country_grp[['Confirmed Cases', 'New Cases']].agg(['count', 'mean', 'std', 'min', 'median', 'max', 'sum']).loc[['United States']]
# Out:
#               Confirmed Cases                                        \
#                         count          mean           std       min
# Country
# United States             104  9.217607e+07  2.705211e+06  86990778
#
#                                                 New Cases                \
#                    median       max         sum     count          mean
# Country
# United States  92616130.0  95768783  9586311709       104  85878.519231
#
#
#                         std   min   median     max      sum
# Country
# United States  62875.524346  4264  80724.5  237315  8931366

# %%
country_grp[['Confirmed Cases', 'New Cases']].describe().loc[['Brazil']]
# Out:
#         Confirmed Cases                                                       \
#                   count          mean            std         min         25%
# Country
# Brazil            104.0  3.405701e+07  644533.198091  32434063.0  33693264.5
#
#                                             New Cases             \
#                 50%         75%         max     count       mean
# Country
# Brazil   34274550.5  34568833.0  34731539.0     104.0  22823.625
#
#
#                   std  min  25%      50%      75%       max
# Country
# Brazil   23386.797931  0.0  0.0  18302.0  37816.5  107959.0

# %%
country_grp[['Confirmed Cases', 'New Cases']].agg(['count', 'mean', 'std', 'min', 'median', 'max', 'sum']).loc[['Brazil']]
# Out:
#         Confirmed Cases                                                     \
#                   count          mean            std       min      median
# Country
# Brazil              104  3.405701e+07  644533.198091  32434063  34274550.5
#
#                               New Cases                                        \
#               max         sum     count       mean           std min   median
# Country
# Brazil   34731539  3541929425       104  22823.625  23386.797931   0  18302.0
#
#
#             max      sum
# Country
# Brazil   107959  2373657

# %%
country_grp[['Confirmed Cases', 'New Cases']].sum().rename(columns={'Confirmed Cases' : 'Total Confirmed Cases', 'New Cases' : 'Total Confirmed Cases'})
# Out:
#                     Total Confirmed Cases  Total Confirmed Cases
# Country
# Afghanistan                      19875815                  18201
# Albania                          33078107                  51704
# Algeria                          27973191                   4635
# American Samoa                     810323                   1836
# Andorra                           4753178                   2592
# ...                                   ...                    ...
# Wallis and Futuna                   71876                    307
# West Bank and Gaza               71818056                  42951
# Yemen                             1237430                    115
# Zambia                           34452504                   7767
# Zimbabwe                         26693520                   2212
#
# [234 rows x 2 columns]

# %%
country_grp[['Confirmed Cases', 'New Cases']].sum().loc[['United States', 'Brazil','Japan', 'China', 'Canada', 'Russia']]\
            .rename(columns={'Confirmed Cases' : 'Total Confirmed Cases', 'New Cases' : 'Total New Cases'})
# Out:
#                Total Confirmed Cases  Total New Cases
# Country
# United States             9586311709          8931366
# Brazil                    3541929425          2373657
# Japan                     1695177697         12306907
# China                      795697140          3920541
# Canada                     432093261           355573
# Russia                    1995270570          2784190

# %%
df.groupby(['Date'])[['Confirmed Cases', 'New Cases']].sum()
# Out:
#             Confirmed Cases  New Cases
# Date
# 2022-07-01        548783533     936849
# 2022-07-02        549142295     358762
# 2022-07-03        549502775     360480
# 2022-07-04        550401093     898318
# 2022-07-05        551589703    1188610
# ...                     ...        ...
# 2022-10-08        621244563     217733
# 2022-10-09        621462675     218112
# 2022-10-10        621965288     502613
# 2022-10-11        622605734     640605
# 2022-10-12        623193429     589603
#
# [104 rows x 2 columns]

# %%
#df.groupby(['Date']).get_group('2022-10-11')[['Confirmed Cases', 'New Cases']].sum()
df.groupby(['Date'])[['Confirmed Cases', 'New Cases']].sum().loc[['2022-07-01','2022-08-15', '2022-10-12']].rename(columns={'Confirmed Cases' : 'Total Confirmed Cases', 'New Cases' : 'Total New Cases'})
# Out:
#             Total Confirmed Cases  Total New Cases
# Date
# 2022-07-01              548783533           936849
# 2022-08-15              591266446           873360
# 2022-10-12              623193429           589603

# %%
country_grp[['Confirmed Cases', 'New Cases']].sum().rename(columns={'Confirmed Cases' : 'Total Confirmed Cases (All Countries):', 'New Cases' : 'Total New Cases (All Countries):'}).sum()
# Out:
# Total Confirmed Cases (All Countries):    61561169727
# Total New Cases (All Countries):             75378005
# dtype: int64

# %%
df.groupby(['Date'])[['Confirmed Cases', 'New Cases']].sum().rename(columns={'Confirmed Cases' : 'Total Confirmed Cases (All Countries):', 'New Cases' : 'Total New Cases (All Countries):'}).sum()
# Out:
# Total Confirmed Cases (All Countries):    61561169727
# Total New Cases (All Countries):             75378005
# dtype: int64

# %%
df.groupby(['Date'])[['Confirmed Cases', 'New Cases']].describe()
# Out:
#            Confirmed Cases                                            \
#                      count          mean           std  min      25%
# Date
# 2022-07-01           234.0  2.345229e+06  7.724829e+06  0.0  21169.0
# 2022-07-02           234.0  2.346762e+06  7.727809e+06  0.0  21169.0
# 2022-07-03           234.0  2.348302e+06  7.730034e+06  0.0  21169.0
# 2022-07-04           234.0  2.352141e+06  7.741878e+06  0.0  21169.0
# 2022-07-05           234.0  2.357221e+06  7.757523e+06  0.0  21169.0
# ...                    ...           ...           ...  ...      ...
# 2022-10-08           234.0  2.654891e+06  8.613703e+06  0.0  22025.0
# 2022-10-09           234.0  2.655823e+06  8.615148e+06  0.0  22025.0
# 2022-10-10           234.0  2.657971e+06  8.621822e+06  0.0  22025.0
# 2022-10-11           234.0  2.660708e+06  8.629361e+06  0.0  22056.5
# 2022-10-12           234.0  2.663220e+06  8.637446e+06  0.0  22063.0
#
# ...

# %%
df.groupby(['Date'])[['Confirmed Cases', 'New Cases']].agg(['count', 'mean', 'std', 'min', 'median', 'max', 'sum'])
# Out:
#            Confirmed Cases                                            \
#                      count          mean           std min    median
# Date
# 2022-07-01             234  2.345229e+06  7.724829e+06   0  169424.5
# 2022-07-02             234  2.346762e+06  7.727809e+06   0  169424.5
# 2022-07-03             234  2.348302e+06  7.730034e+06   0  169438.0
# 2022-07-04             234  2.352141e+06  7.741878e+06   0  169446.5
# 2022-07-05             234  2.357221e+06  7.757523e+06   0  170538.5
# ...                    ...           ...           ...  ..       ...
# 2022-10-08             234  2.654891e+06  8.613703e+06   0  196501.5
# 2022-10-09             234  2.655823e+06  8.615148e+06   0  196586.5
# 2022-10-10             234  2.657971e+06  8.621822e+06   0  196635.0
# 2022-10-11             234  2.660708e+06  8.629361e+06   0  198109.5
# 2022-10-12             234  2.663220e+06  8.637446e+06   0  197207.0
#
# ...

# %%
def total(x):
  return x.sum()

df.groupby(['Country'])[['Confirmed Cases', 'New Cases']].apply(total).loc[['South Africa', 'Antarctica', 'Ethiopia']].rename(columns={'Confirmed Cases' : 'Total Confirmed Cases', 'New Cases' : 'Total New Cases'})

#     OR

#country_grp[['Confirmed Cases', 'New Cases']].apply(total).loc[['United States']].rename(columns={'Confirmed Cases' : 'Total Confirmed Cases', 'New Cases' : 'Total New Cases'})
# Out:
#               Total Confirmed Cases  Total New Cases
# Country
# South Africa              416958394            28663
# Antarctica                     1144                0
# Ethiopia                   51220631             4999

# %%
df.groupby(['Date'])[['Confirmed Cases', 'New Cases']].apply(total)
# Out:
#             Confirmed Cases  New Cases
# Date
# 2022-07-01        548783533     936849
# 2022-07-02        549142295     358762
# 2022-07-03        549502775     360480
# 2022-07-04        550401093     898318
# 2022-07-05        551589703    1188610
# ...                     ...        ...
# 2022-10-08        621244563     217733
# 2022-10-09        621462675     218112
# 2022-10-10        621965288     502613
# 2022-10-11        622605734     640605
# 2022-10-12        623193429     589603
#
# [104 rows x 2 columns]

# %%
display(df.groupby(['Country'])[['Confirmed Cases', 'New Cases']].apply(total)
      .loc[['West Bank and Gaza', 'Panama', 'Papua New Guinea', 'Paraguay',
      'Peru']].rename(columns={'Confirmed Cases' : 'Total Confirmed Cases', 'New Cases' : 'Total New Cases'}),
      df.groupby(['Country'])[['Confirmed Cases', 'New Cases']].apply(total)
      .loc[['Philippines', 'Pitcairn Islands','Iceland']]
      .rename(columns={'Confirmed Cases' : 'Total Confirmed Cases', 'New Cases' : 'Total New Cases'}))
# Out:
#                     Total Confirmed Cases  Total New Cases
# Country
# West Bank and Gaza               71818056            42951
# Panama                          100333145            66916
# Papua New Guinea                  4666021              429
# Paraguay                         73308008            61507
# Peru                            414809161           522638
#                   Total Confirmed Cases  Total New Cases
# Country
# Philippines                   399667799           268684
# Pitcairn Islands                    340                4
# Iceland                        21110471            11976

# %%
a = country_grp[['Confirmed Cases']].sum().loc[['United States']].value_counts()
a
# Out:
# Confirmed Cases
# 9586311709         1
# dtype: int64

# %%
b = country_grp[['Confirmed Cases']].sum().sum().value_counts()
b
# Out:
# 61561169727    1
# dtype: int64

# %%
#c = a/b
#c

print("The United States has", str((9586311709/61561169727)*100) + "% of the World's confirmed Covid-19 cases!")
# Out:
# The United States has 15.572010329744526% of the World's confirmed Covid-19 cases!

# %%
x = country_grp[['New Cases']].sum().loc[['United States']].value_counts()
x
# Out:
# New Cases
# 8931366      1
# dtype: int64

# %%
y =country_grp[['New Cases']].sum().sum().value_counts()
y
# Out:
# 75378005    1
# dtype: int64

# %%
#z = x/y
#z

print("The United States has", str((8931366/75378005*100)) + "% of the World's new Covid-19 cases!")
# Out:
# The United States has 11.848769412244328% of the World's new Covid-19 cases!

# %%
country_grp['Confirmed Cases'].value_counts()
# Out:
# Country      Confirmed Cases
# Afghanistan  191967             3
#              182793             2
#              193520             2
#              182594             1
#              182643             1
#                                ..
# Zimbabwe     257342             1
#              257376             1
#              257517             1
#              257538             1
#              257798             1
# Name: Confirmed Cases, Length: 11017, dtype: int64

# %%
country_grp['New Cases'].value_counts(normalize=True) * 100
# Out:
# Country      New Cases
# Afghanistan  0            3.846154
#              186          2.884615
#              49           1.923077
#              72           1.923077
#              81           1.923077
#                             ...
# Zimbabwe     86           0.961538
#              87           0.961538
#              103          0.961538
#              104          0.961538
#              140          0.961538
# Name: New Cases, Length: 9398, dtype: float64

# %%
country_grp['New Cases'].value_counts(normalize=True).loc['United States'] * 100
# Out:
# New Cases
# 4264      0.961538
# 5020      0.961538
# 5064      0.961538
# 5433      0.961538
# 5548      0.961538
#             ...
# 199303    0.961538
# 200215    0.961538
# 201676    0.961538
# 212589    0.961538
# 237315    0.961538
# Name: New Cases, Length: 104, dtype: float64

# %%
country_grp['New Cases'].value_counts()
# Out:
# Country      New Cases
# Afghanistan  0            4
#              186          3
#              49           2
#              72           2
#              81           2
#                          ..
# Zimbabwe     86           1
#              87           1
#              103          1
#              104          1
#              140          1
# Name: New Cases, Length: 9398, dtype: int64

# %%
country_grp['New Cases'].value_counts(normalize=True) * 100
# Out:
# Country      New Cases
# Afghanistan  0            3.846154
#              186          2.884615
#              49           1.923077
#              72           1.923077
#              81           1.923077
#                             ...
# Zimbabwe     86           0.961538
#              87           0.961538
#              103          0.961538
#              104          0.961538
#              140          0.961538
# Name: New Cases, Length: 9398, dtype: float64

# %%
country_grp['New Cases'].value_counts(normalize=True).loc['United States'] * 100
# Out:
# New Cases
# 4264      0.961538
# 5020      0.961538
# 5064      0.961538
# 5433      0.961538
# 5548      0.961538
#             ...
# 199303    0.961538
# 200215    0.961538
# 201676    0.961538
# 212589    0.961538
# 237315    0.961538
# Name: New Cases, Length: 104, dtype: float64
